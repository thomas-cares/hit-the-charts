# %% [markdown]
# # IMPORT

# %%
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import spotipy.oauth2 as oauth2
import json
import pandas as pd
import numpy as np
import requests
import re
import os
import datetime
from datetime import date, timedelta
from datetime import datetime
import glob
import time

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # AUTHENTIFICATION
# * guide for authentification with Spotify API: https://developer.spotify.com/documentation/general/guides/authorization-guide/
# * calling personal credentials from environment https://able.bio/rhett/how-to-set-and-get-environment-variables-in-python--274rgt5
# * open in terminal: touch ~/.bash_profile; open ~/.bash_profile
# * implement: source ~/.bash_profile
# * get new token https://developer.spotify.com/console/put-playlist/

# %% [markdown]
# #### Create and refresh token
# run this to  refresh the token. Token runs out every 3600 seconds.

# %%
my_client_id=os.getenv('spoti_CLIENT_ID')
my_client_secret=os.getenv('spoti_CLIENT_SECRET')

my_client_id=os.getenv('spoti_CLIENT_ID')
my_client_secret=os.getenv('spoti_CLIENT_SECRET')
sp=spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=my_client_id, client_secret=my_client_secret))


#token to pull songs of an individual usersp_pers=spotipy.Spotify(cache_token_personal)
cache_token_personal= '' 
sp1=spotipy.Spotify(cache_token_personal)

# %% [markdown]
# # CRAWLING FOR CHARTS
# HERE WE DOWNLOAD CSVs FORM www.spotifycharts.com

# %% [markdown]
# ### Function
# downloads CSVs from spotifycharts.com given the countries of choice and the time interval set below
#
# * Note: this depends on the availability of the CSVs on spoitifycharts.com . Error may occure if we are trying to pull data for a day spotify does not provide charts data for. Slightly adapting frequency or start and end date might shift you around thos "data holes"

# %%
#DOWNLOAD LOOP FOR COUNTRY AND FOR TIME PERIOD
# prepare a folder named 'data' with two subfolders named 'viral' and 'regional'
def bulk_charts_download(country_charts, date_list):
    for country in country_charts:
        for date in date_list:
            url= f'https://spotifycharts.com/{what_charts}/{country}/daily/{date}/download'
            r = requests.get(url, allow_redirects=True)
            open(f'data/{what_charts}/{date}-{country}-{what_charts}.csv', 'wb').write(r.content)

# %% [markdown]
# ### SET PARAMETERS FOR CRAWLING

# %% [markdown]
# #### Set Start and End Date

# %%
startdate = date(2017, 1, 1)   # start date
enddate = date(2021,1,30)   # end date
delta = enddate - startdate       # as timedelta

date_list=[]

for i in range(delta.days+1):
    day = startdate + timedelta(days=i)
    date_list.append(day.strftime("%Y-%m-%d"))

# %% [markdown]
# #### Chose frequency
# between start date and end date how often do we pull charts data

# %%
date_list=date_list[0::90] #every 90 days

# %% [markdown]
# #### Country Codes

# %%
#enter list of country codes
country_charts=['at','be','bg','br','ca','ch','cl','co','cr','cz','de','dk','ec','es','fi','fr','gb','gr','is','ie','it','mx','nl','no','pe','pl','pt','ro','ru','se','tr','us']
#HELP: LIST OF COUNTRY CHARTS
print(len(country_charts))
print(sp.country_codes)
# Out:
# 32
# ['AD', 'AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'EC', 'SV', 'EE', 'FI', 'FR', 'DE', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'ID', 'IE', 'IT', 'JP', 'LV', 'LI', 'LT', 'LU', 'MY', 'MT', 'MX', 'MC', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'ES', 'SK', 'SE', 'CH', 'TW', 'TR', 'GB', 'US', 'UY']

# %% [markdown]
# #### Which charts are we crawling
# Options: viral charts or regional top200

# %%
# VIRAL CHART sample URL https://spotifycharts.com/viral/us/daily/2020-03-13/download
# thats how i want filename to be safed regional-us-weekly-2020-03-13--2020-03-20.csv

# enter as string 'viral' for viral top 50 or 'regional' for local top 200
what_charts='regional'

# %% [markdown]
# #### Trigger download CSVs to folder: Calls function with parameters set above

# %%
bulk_charts_download(country_charts, date_list)

# %% [markdown]
# # CREATE DATAFRAMES

# %% [markdown]
# #### create dataframe from csvs
# * intermediate step before adding music features

# %% [markdown]
# #### FUNCTION CSVs to Data Frames
# * additionally extracts data on country, date and song IDs form the original URLs

# %%
def csv_to_dataframe(what_charts):
    path = f'data/{what_charts}/'                     # use your path
    all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

    df = [] # pd.concat takes a list of dataframes as an agrument
    for csv in all_files:
        
        # if condition since csv of top200 look differently than csvs from viral charts.
        # top 200 sharts do have a disclaimer not in the first line that messes with our columns upon import
        # we need to igonre it
        if what_charts=='regional': 
            frame = pd.read_csv(csv,skiprows=[0],error_bad_lines=False, warn_bad_lines=True)
            frame=frame.drop('Streams',axis=1)
        #this is the read in for viral charts csvs
        else:
            frame = pd.read_csv(csv,skiprows=[],error_bad_lines=False, warn_bad_lines=True)
        
        frame['filename'] = os.path.basename(csv)
        df.append(frame)
        
    #concat list of dataframes into 1
    df=pd.concat(df, ignore_index=True) 
    
    #finetuning columns with regex
    df['ID']= re.findall(r'\d\w+',str(list(df['URL']))) #extract ID from URL
    df['date']=re.findall(r'\d\d\d\d-\d\d-\d\d', str(list(df['filename'])))
    df['date']=pd.to_datetime(df.date, format="%Y-%m-%d", yearfirst=True)
    df['country']=re.findall(r'-[a-z][a-z]-', str(list(df['filename'])))
    df['country']=re.findall(r'[a-z][a-z]',str(list(df['country'])))
    
    # indicates if song is from viral charts or top 200 charts/ 'regional' indicates its part of  regional top200 charts hence we label it 'top200'
    df['group']=np.where(what_charts=='regional','top200',what_charts) 
    return df

# %%
charts_df_basic=csv_to_dataframe('regional')#pass in bracket if 'viral' or 'regional'
len(charts_df_basic)
# Out:
# 97173

# %% [markdown]
# # SUBSETTING VIRAL CHARTS
# * to make the project feasible for my processing means I need to subset
# * my machine is able to make approx 6300 calls to the api per hour
# * spotify token expires after 1 hour
# * subsetting to the top 20 of 32 countries between 01/01/2017 and 31/12/2020 at 16 sample dates
# * ending up with almost 5872 ids to represent 13827 entries

# %%
# unique song id: plenty of songs are in teh charts multiple time for different countries and at different dates
# lets see how many IDs are unique since we dont want to pull features for the same song multiple times
unique_ids=list(charts_df_basic.ID.unique())
len(unique_ids)
# Out:
# 20156

# %%
# lets return all unique IDs of songs that are at one point place in the top200 charts in any country at any time
# and lets check how many unique IDs are left if we subset for only the top 20
#we use this to set the size of our data set
unique_ids_of_top20charts=set(charts_df_basic['ID'][charts_df_basic['ID'].isin (unique_ids) & charts_df_basic['Position'].isin(list(range(1,21)))])
len(unique_ids_of_top20charts)
# Out:
# 3272

# %%
# using the top 20 of each countries viral charts at all sample points results in 5872 unique IDs
# thats below my 6300 ongs threashhold

# %%
#
charts_df_basic_top20=charts_df_basic[charts_df_basic['Position'].isin(list(range(1,21)))]
charts_df_basic_top20.shape
# Out:
# (10079, 9)

# %%
len(charts_df_basic_top20.ID.unique())
# Out:
# 3272

# %% [markdown]
# # INSPECT DATAFRAME

# %%
charts_df_basic_top20.head()
# Out:
#    Position                 Track Name          Artist  \
# 0         1                   Relación            Sech
# 1         2                   Favorito          Camilo
# 2         3  Elegí (feat. Dímelo Flow)  Rauw Alejandro
# 3         4                    Safaera       Bad Bunny
# 4         5                     Tattoo  Rauw Alejandro
#
#                                                  URL  \
# 0  https://open.spotify.com/track/3ZG8N7aWw2meb6U...
# 1  https://open.spotify.com/track/0jT8Nl0shPS8115...
# 2  https://open.spotify.com/track/50ZC4PM7hywH27R...
# 3  https://open.spotify.com/track/2DEZmgHKAvm41k4...
# 4  https://open.spotify.com/track/7na7Bk98usp84Fa...
#
#                      filename                      ID       date country  \
# 0  2020-06-14-pe-regional.csv  3ZG8N7aWw2meb6UrI5ZmnZ 2020-06-14      pe
# 1  2020-06-14-pe-regional.csv  0jT8Nl0shPS8115is0wD2Q 2020-06-14      pe
# 2  2020-06-14-pe-regional.csv  50ZC4PM7hywH27RcCfViau 2020-06-14      pe
# 3  2020-06-14-pe-regional.csv  2DEZmgHKAvm41k4J3R2E9Y 2020-06-14      pe
# 4  2020-06-14-pe-regional.csv  7na7Bk98usp84FaOJFPv3d 2020-06-14      pe
#
#     group
# 0  top200
# 1  top200
# 2  top200
# 3  top200
# 4  top200

# %%
#are their songs that are in the charts of muliple countries ?
pd.pivot_table(charts_df_basic_top20,index=["Track Name",'Artist'], values=['country','ID'], aggfunc={'country':np.sum,'ID':'count'}).sort_values('ID',ascending=False).head(5)
# Out:
#                                               ID  \
# Track Name                      Artist
# Blinding Lights                 The Weeknd    85
# Dance Monkey                    Tones And I   77
# Shape of You                    Ed Sheeran    73
# rockstar                        Post Malone   56
# All I Want for Christmas Is You Mariah Carey  54
#
#                                                                                         country
# Track Name                      Artist
# Blinding Lights                 The Weeknd    pecarurofrrobefiptfrptroecchpliesenlchiebggbdk...
# Dance Monkey                    Tones And I   iecocapltrczesrogbbgfrptbrrobeptnodebrchplieco...
# Shape of You                    Ed Sheeran    atplchcoieesczptbggbfrbritdecrbetrdenodkcrtrpl...
# rockstar                        Post Malone   iscacafiitisgrusbedknlbesegrdkbecrususnlgrseca...
# All I Want for Christmas Is You Mariah Carey  ieplcaisitdkfibesenlusnogrdkgriscanlseczgbbgbe...

# %%
#anything empty?
charts_df_basic_top20.isnull().sum()
# Out:
# Position      0
# Track Name    0
# Artist        0
# URL           0
# filename      0
# ID            0
# date          0
# country       0
# group         0
# dtype: int64

# %%
#NAN values
charts_df_basic_top20[charts_df_basic_top20['Artist'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Position, Track Name, Artist, URL, filename, ID, date, country, group]
# Index: []

# %%
# how many songs per country 
charts_df_basic_top20['country'].value_counts()
# Out:
# cl    340
# co    340
# cr    340
# pe    340
# mx    340
# us    340
# pl    340
# fi    340
# it    340
# gr    340
# no    340
# ca    340
# be    340
# dk    340
# cz    340
# es    340
# se    340
# ec    340
# ie    340
# br    340
# pt    340
# fr    340
# tr    340
# nl    320
# gb    320
# ch    320
# at    300
# de    280
# is    240
# ro    240
# bg    199
# ru     40
# Name: country, dtype: int64

# %% [markdown]
# # CALL API FOR MUSIC FEATURES

# %% [markdown]
# ### FUNCTION: GET MUSIC FEATURES FROM API

# %%
def getTrackFeatures(df):
    feature_names=['ID','duration_ms', 'popularity', 'acousticness','danceability', 'energy', 'key','instrumentalness', 'liveness', 'loudness', 'mode','speechiness', 'valence', 'tempo','loud_start']
    features_df=pd.DataFrame(columns=feature_names)
    
    causing_error=[]
    
    for id in set(df['ID']):#only loop through the unique IDs to enhance performance
        try:
            print(id)
            meta = sp.track(id)
            features = sp.audio_features(id)
            analysis= sp.audio_analysis(id) #does not seem to be available at all songs

            #collect in dictionary
            features_dict = {}   

        
            # meta
            features_dict['ID']=meta['id']
            features_dict['duration_ms'] = meta['duration_ms']
            features_dict['popularity'] = meta['popularity']
            # features
            features_dict['acousticness'] = features[0]['acousticness']
            features_dict['danceability'] = features[0]['danceability']
            features_dict['energy'] = features[0]['energy']
            features_dict['key'] = features[0]['key']
            features_dict['instrumentalness'] = features[0]['instrumentalness']
            features_dict['liveness'] = features[0]['liveness']
            features_dict['loudness'] = features[0]['loudness']
            features_dict['mode'] = features[0]['mode']
            features_dict['speechiness'] = features[0]['speechiness']
            features_dict['valence']=features[0]['valence']
            features_dict['tempo'] = features[0]['tempo']
            #analysis
            features_dict['loud_start']=analysis['sections'][0]['loudness']#loundness at the start
        
        #error handling
        except:
            causing_error.append(id)
            print('causing error: ',causing_error)
            
        #wrap up of all gathered features
        track_df = pd.DataFrame(features_dict,index=[0],columns=features_dict.keys())
        features_df = pd.concat([features_df, track_df], axis=0, ignore_index = True)#concatinating along axis 0
    return features_df
    #lst_columns=['Position','Track Name','Artist','URL','filename','ID','date','country','group','duration_ms', 'popularity', 'acousticness','danceability', 'energy', 'instrumentalness', 'liveness', 'loudness','mode', 'speechiness', 'valence', 'tempo','loud_start']
    #df_with_features=pd.concat([df,features_df],axis=1,ignore_index = True)
    #df_with_features.columns=[list(df.columns)+list(features_df.columns)]#creates new joined list of columns
    #return df_with_features

# %% [markdown]
# #### call API on IDs returning a dataframe with features of each ID

# %%
#dataframe of features
charts_features_df=getTrackFeatures(charts_df_basic_top20) #get features for each song
# Out:
# 1XzdeTK7eQulR42YCb66La
# 7sQKy5vlPQllr0k9IjYJv3
# 2NUIWpL6IsYGkwfSN7basS
# 49bgQMlDHljkVGRsHtsFJC
# 3Z3QhZAZpqwZa1phsbQ3JZ
# 4ofwffwvvnbSkrMSCKQDaC
# 6h5nbfvIJHRNH3oGrNWJwn
# 1X3ltingEVNGRoJf1dvZfQ
# 5qFeMRz4TvetPmzjre9Dq7
# 7D2sgT3LkRnl6I7hunrsoj
# 2MbdDtCv5LUVjYy9RuGTgC
# 73Ec1iE2MDm6Y16Tq2Rz8O
# 1GOiMxQXZUzjzH0Sxpck0B
# 4kuexchmxuc5NXmokfo1WH
# 6alIH9pO3MTVW56AzSuDGj
# 2KK9N6iBAisA0booTu3bGd
# 1AgqELuodwiIUbJhXM74Jx
# 1cPbUxHuNnSVQbukUrnY8O
# 4fUCTv421fKbSRFKuPi6ge
# 5RQ3ZyfOfJJ2qLKOZTmLiB
# 4MzXwWMhyBbmu6hOcLVD49
# 7aCtjju6kQ316xn95FIOGq
# 5LBikzSkad9yQ6RH87Gdrm
# 7dt6x5M1jzdTEt8oCbisTK
# 3Uq45ipGutypFPmETfaoaH
# 1fpmB97puEtPLW9ui8qEBw
# 4rTZbEQtDtlZZW1Ag9Umbk
# 1m69ELEgE6k5ZWsap40ozt
# 2Oycxb8QbPkpHTo8ZrmG0B
# 0J6sITdD8JMUBKaadJLV1U
# 524euygKKFWurhvIdSrkg6
# 7fTsw0IKbbPDN19keS32tF
# 72sOrgrynSH73z4E41Ed0i
# 6zeeWid2sgw4lap2jV61PZ
# 75AtrLBAWdyTXs2TDAAIN3
# 6mhojtIauujcoXxlGsihh1
# 6KF78W66DcQ9m5YqR0r5Ig
# 4Mm7SmGjH8YNQV3GDtCGkL
# 76KDy62J99FKu6ZsxMJy3j
# 6LsAAHotRLMOHfCsSfYCsz
# 2H1liABu20HXBOmbt5SQz1
# 0Wq6iAraiUpSbBSPmv4gLu
# 4lzxJ4jCuFDXXGkE1LmpKR
# 5lylTIELvRSbDYKQyrOWBa
# 63SevszngYpZOwf63o61K4
# 2pJZ1v8HezrAoZ0Fhzby92
# 7stwYkvAuyfMD8LUK2vBd7
# 4qknM1pQz53QOyfDVTjcM9
# 514rhnksEwHUh6LxXsQ4Y9
# 4okba5wu9mMLXx79DXLKi3
# 0H7cz1bR7w9PulJL7Na774
# 5hM6sP0Gh1jD57drszNueC
# 0dLToDou8YHYJpQltj3Ijy
# 0qvfIq8RsH3sOZk9JIuUhn
# 5foznJ5MF2UvnrOE2pN6oN
# 7AFASza1mXqntmGtbxXprO
# 37uOqc0bL4GBiG5Dpm6dQf
# 7wGoVu4Dady5GV0Sv4UIsx
# 4RcEx6TvICENelSh3O7gvu
# 4QXLXEcGPl18ghSz4cSEzP
# 4DVPJXPqKLIon9BHklap1w
# 5rRGbD1s7gQWnWwn0O3no2
# 27OWNTEEtJCFVejrh5mqgv
# 4XI1EwZQWuWrDgPtyOk6UF
# 3QfD4bxxkopZL7XZ8RaezH
# 3DGar7krWlmrXRFHBcQF6z
# 6EDnqtAZxZu5pGXyPjgvU8
# 0tgVpDi06FyKpA1z0VMD4v
# 0OyfyAIHIdERPduy0omDj4
# 05HKKlHqE1HJ1oIqXpJ7yI
# 6R6on0ldJcSDfi2whJziJ1
# 5HsBJenkDnrzim7o7uKwQq
# 11VyWPLK8nQqZEpsg2rkww
# 4DnHUy01jEA4b5ydC3HgsT
# 1H7KnK26kc1YyellpbINEn
# 6fTsxhIosAU6zXTAhSaemI
# 3O6wEE1kLBhfGIYbx4fZPy
# 6CUP2khYzdphXebxVTfPE3
# 638s8Qi75q1pXjuH86fJX7
# 45zJRuzK9e6AO527NOW7Fy
# 7j8K8PE1tO2TvhY15E8ZcD
# 3sgGmPQD2J6aQduN36RDBO
# 4VVG3HBGaqSNZqIpmewIA6
# 2YGqtxaGdML9aM5jCwgRw9
# 5stPVcRqb4qixbafP9e8lt
# 3ibRxEv4KkcU9e259eyNJA
# 0dA2Mk56wEzDgegdC6R17g
# 0ewiq9snqyF3dULzbMqI3J
# 74HpGbP9e5oOdeY6XxcGP3
# 3g7SvCfzTu23cZpKwcEVKq
# 6I6NX6tjGsxFAsIfGzY9lJ
# 5WytJMdICvcrJF6JY0W4pl
# 6XHVuErjQ4XNm6nDPVCxVX
# 4dRfu7exVh3sUekkCtZJlS
# 7EAg6R0bwKcJzZgikPbPYX
# 2nY6MRHWpW0AGXMoGDJOjX
# 40bK2uosUmAS92c17n98xd
# 5jpgdY7oK3z09QCLZwPM3o
# 4oi4BFWbw2r9el8D9aVue3
# 3TnhQSRwT3AVMdXw5JPq0x
# 0dZpw3h6KZhcHec61qwevZ
# 27RYrbL6S02LNVhDWVl38b
# 3N5AZtKJALZZDHT4On8Ebx
# 1uPPyvMOaaVLnVcwD1Sp0d
# 18MGgjSmKP7971VFFgJU94
# 0ERbK7qVqveCaBWIiYCrl3
# 0AaV4MJrgmLV3XhoiWXjjb
# 7y4ELJ02ZssUMSkJiTfq2o
# 58st6r10Ze6QomHs0BMUA8
# 5Q2P43CJra0uRAogjHyJDK
# 3iYv5nIthPXesF0DeuhmVL
# 0qA2qykpcGdVl3tiiYum4g
# 5S7YAM3lcfPNBSTVyciwCu
# 24mpJgP2YZUBif9NvmYyh4
# 0yd4OCmrcqvsAMUJGCMEFQ
# 5i50gKdLAjjIr7UxRT5IVy
# 2alIsNw1mqEShbWyO1HXZZ
# 1JBqLoGfH1LnGTE0wzAatU
# 2NPiBHafyMwJXvSemJ2S0F
# 27lKzu8eKwNUxtTUvSDpBN
# 50ZC4PM7hywH27RcCfViau
# 7vgv8KZBSo0TPzyIWG9yzV
# 1vE38ibMSYKjDc82vY9pcq
# 2vEY3cNwXYxIG4fPAoN14q
# 7rLegaz7zKB6EtDNzcslKE
# 49vQclrdXkZXMJnD0VN3qZ
# 5PYQUBXc7NYeI1obMKSJK0
# 5uCOcuo0qjDhkSmYQI3Bwx
# 1xyVMQx51Kab6eLVtE6twx
# 5Edm7dgoK4dkWF7IyeMZaZ
# 3aMI0cu9YaZfyJTJMS89Ey
# 3590AAEoqH50z4UmhMIY85
# 0nkDm27DGppCSk8dnGtvPa
# 5ePePcvp5FnkuzjxnQdQbf
# 4Sokm1cWK36H2WctWWRGf1
# 2c80HnIOPMmQQVQllQEWb5
# 6BZhkqUtaFJm57Hm5TTQSH
# 5lyTvBqxtjyPray48fCWgj
# 5M9phYS7KgM3ZXKTSlgLv0
# 0vPVqOKo8LWVganQgBZS5y
# 5N5k9nd479b1xpDZ4usjrg
# 03x2rVJRFUrvwlfxoHd9Mo
# 07f2HejhuIzp37RK60brsJ
# 5GmOQzK89STZgfjwBlwrui
# 7gwwt1IaAWwmB7af0AcuBM
# 6erIvryBSsAdebNU4a7Mrs
# 7xP9xGroL8AoI7t2ik4KRy
# 2RSHsoi04658QL5xgQVov3
# 6X0pg9AHaLYLq8Cy5j8Suz
# 2XW4DbS6NddZxRPm5rMCeY
# 3aRgAfrt6aQW8IimLq2aVG
# 30KctD1WsHKTIYczXjip5a
# 4LZi20EAgNBhTR3OBWLzdr
# 4T4AhK8ENsdc2zB6IzyjsI
# 40XC3Fre6dJ2JzmYKsKhUU
# 2K7kTu0pI07RoWgwofGzSD
# 6tjituizSxwSmBB5vtgHZE
# 78KyOmqWmqLkQcXO1cA7MO
# 1qfoq1qvZT7VwDVeekCJ97
# 63aad0ckWuHWeBgib3DNeK
# 73mCHQiEZ8ljealH38vvVH
# 2UZW9WOPXdxw9YMG1bebS8
# 03GRTPQ4N97BvCF1lGoIj7
# 7nPTjuVySLIUlgKrzTIFdb
# 284ABgw7KmrZj81h4kIc3l
# 14KKXLz5WHrzGOMUNFV22H
# 4pzE97EZMDxnqO88y3YxAm
# 4LTHcXXwN8OW4fYm5sVNPP
# 1mF6sMUsRU9MisrdB9qWvg
# 5EGO6sCOZuracSGyAPvu3F
# 1IPRghUN3LFPNbCTsfBJx9
# 7uttm8Iurm5uK67Vr9G2Sp
# 44W4kdPFIt6tRy4cw1mUA6
# 2PAYSgrVOBz8RJqp9B7QLu
# 4jsgazk5mn6jzpa9IJkfnx
# 2MCAs3ttHSuDm1RHL0rqTF
# 2PS6YQ9jMpm0uCg4sQ1ygm
# 2Ro1i5jA2krJYkFJOrRrFa
# 1gG0pnDAT1QdpRFTQDT4y4
# 6uW0PIRcyZLvkoonm763xD
# 12GV2Wr4p1hBWQCrQcVsew
# 3CPBzUohQI0fVoFFMSZouO
# 3twi0u2fGElT0lpimmK77i
# 4lzjE9GlGamkuYqQBfCY8R
# 4yPM3zOeanKO3OpBGHdrBI
# 2C6WXnmZ66tHhHlnvwePiK
# 1LO951RWD10l9Vys0NrFty
# 0JoHqmlqE0W0i9prt6kcHR
# 3e0gMtgOOLGPFLzPWR7xzb
# 216QmkNpU3hIjeZtGocb9B
# 7IJIj326qJJA6oi6EpFCBD
# 3rwuYQM6eEqTLWapNYAeZD
# 4XA22ZDMhpoepUBy1bJHVM
# 54oMZ3blwWwuPN4wEoG5mk
# 1ZBzQaqJKdyZ7y8Tm6CJ32
# 2z4pcBLQXF2BXKFvd0BuB6
# 14k0poH7ibLhg4kz4PGKSJ
# 0QIjsbm2fh1cJ45XO9eGqq
# 1WqP758rbjGxxZQm28PBme
# 7dl9BHIXXkBb3zsgWjRchZ
# 4oH4AouYQw8RopRCjzz1if
# 7n1zPrqGyMqNIpzFb9y1wC
# 6UZJOc2HBrTp9DYfir9N8n
# 0kCqaybZgYcLYxzZymmBoc
# 7iQYp6Fp3xFFatU20GZtLe
# 0bMbDctzMmTyK2j74j3nF3
# 6bey7El3agTSzIRaAdjPg1
# 7DRDJ5ZzU7mj7CfRxGYzOY
# 2TIlqbIneP0ZY1O0EzYLlc
# 0hnErtVKN1JyvfBNfpWDpO
# 5s8LepdwU0THzpd0M7nLsa
# 5SleX0NFeODNY7Xenal3gr
# 3VClLWqNn80Llv0PJOsKgr
# 7tXCV0UwFwBxqum6i25you
# 6zKPL5jWQXhTAPPKLxwC5K
# 2Ybq4O3JksrB02I1glWh65
# 3VvA1wSxukMLsvXoXtlwWx
# 6f3Slt0GbA2bPZlz0aIFXN
# 6yuArSnBrhykjkCxb8eXvl
# 2tFwfmceQa1Y6nRPhYbEtC
# 2hIY4sjfMeKwXXh2LvhrMo
# 1l0cnUKIlkv7moUqGyjNqZ
# 5Jm4w8jmPEBTLjI9vH4fXo
# 67VXzMGtIrbj52tB6D4djH
# 2JvzF1RMd7lE3KmFlsyZD8
# 4aWmUDTfIPGksMNLV2rQP2
# 38lQ7lYhN3eSWepnZHaiBF
# 6n4U3TlzUGhdSFbUUhTvLP
# 07w6jp4Fq8GGqhLoDYoVkb
# 2ILHXpt71eq7mmUPhXONkL
# 2tE91SF5e1xY20syeIaKBh
# 3M72cvOpuPxE7nGXPE1c2y
# 7eBYMVok43QesT0KnuIkjn
# 47xPl1gvgdx4Z9dNUuloPg
# 4NzMOnvSJVNKF7nw5NkXIP
# 3LMQL9CSxvUP2m8FeFszP6
# 7LSpHN7E9EKZo2YovzqOAV
# 0yJshzyh9qjjtiyLBbPglQ
# 6aH3QgooXRmx8k8jzrSm3V
# 71FrGl0XcpL3VId65tB5mg
# 3hBBKuWJfxlIlnd9QFoC8k
# 3QqsEc7mv1Kq9aWNpQgHsU
# 54OB85nuxYGfl7qRQXuz7c
# 7tr2za8SQg2CI8EDgrdtNl
# 7887EjnwYduvgqpPysG50Z
# 3j30Y6jVypcZxFiWATyZ4Y
# 3POGnxIoM4QCQE9SQ2OpE9
# 6Y4PDQv4XjYjHLeLmvyOt0
# 7fUYUcWy853HS8YJn0b3Sr
# 0BwO44CBPFWxAIO5ZbPf3N
# 3sIXzuNgN9HrC7amkEQWiP
# 2Up8QSKRV7WnZxZAQasEUq
# 1VDFn1PCpp8EOXLMURS8kP
# 1pNZLvVjMheeoOpuQqKDIJ
# 2rzZ0IGxgrGUAPwrWn80z7
# 4KkUjFkcQvGvWekl8RATDn
# 0JyOOPqNSdhIC7VrxrRNGt
# 00GxbkrW4m1Tac5xySEJ4M
# 19LqJBBfd73oeBc3CPgDdl
# 1OAh8uOEOvTDqkKFsKksCi
# 0Jf4hAJPvUoPFdDcpoBkqX
# 5wetjrVoUDGhnCfzictqpE
# 6NprDUe0yiLIVGgcnFGgtq
# 13LoCHeSbhEO3YPyMxjgSY
# 2rFZhVHWOwDxAy59qLUzLy
# 6WrI0LAC5M1Rw2MnX2ZvEg
# 3btQ3ZyrZc6iZ8q31gmLu4
# 0DhkTGjEaIHaSxTfC14BFm
# 1AwE3VLo6qlJ2xi1oS3BwE
# 1LNUxWJifZNEPpd273N2le
# 2QpUWi6VSNOt2WyH5FIeLD
# 7C9WUhnC08zjbutkdtQXxH
# 1JapaGk1R2sTBTgqJB4J9f
# 2bN0p91LZmBKmgmpIGu5RI
# 1wjzFQodRWrPcQ0AnYnvQ9
# 5165XjbVxwq9dQDxNk7hmf
# 5b9RQx9CLZRZcO1W8PvmcB
# 2IA8cFA46DkjgbsRG7kKbp
# 4RR1B32xyiyWUk7NfIEb94
# 5o9X0DpYnZvBJ5IRR7ZwiB
# 5PjKlhaFq4J3kAJKLeW30e
# 2ilvTstOiWDmsGf75lz6Ka
# 3WmKdTY0wtkDRd5mAsAB5i
# 79s5XnCN4TJKTVMSmOx8Ep
# 7DRP2VOMpy1rrk3iYFLCW9
# 0LQ1J0BCzA2qnAgp9MkkNE
# 1krkFcdC579tuWC334yn1z
# 197aNKfFNy02if3CpWStRI
# 5m3jpKkgkfoMcym1qjToFg
# 2On7uB8PN8JJmBNsms8unQ
# 575JDrZ0bLVMycVrcBNrhH
# 1xbtojAZsQjOgiGdGX6ChU
# 5wOAQXIydVWJNatT6nKwhz
# 17OUBczN4xbjuCDcx0xmXL
# 7ql2RUmAmj36tkMUNWo7MT
# 55C0glNSvxJDCfgHwiCZb1
# 2bPtwnrpFNEe8N7Q85kLHw
# 6hFmSZIw5gmn9mK4hfqozy
# 247LJ2oARxtQuFAlbPIx79
# 3B54sVLJ402zGa6Xm4YGNe
# 3bCuspxImskpiHF3udYdFI
# 6wo37KVqFJhtuxPTpLCcfe
# 1BxkZE73h9BN3qwuA15TA3
# 7KXjTSCq5nL1LoYtL7XAwS
# 6efE8dnOMEq6omfJK96lCM
# 59SApXnguIQX9gSQVH2Mhl
# 14dBJOQG3mNCZK4m7i684L
# 76OfzNtY3nG5hCnh5COSjt
# 63xr0kuokCreaKuklqDsF5
# 22LAwLoDA5b4AaGSkg6bKW
# 4ofvoCdXq99vpMZO4Cfp8x
# 3fJaqjV813edLN5wrxUPkc
# 1zhfU6YXa2pXUAQdG1NvBZ
# 5X2c4q56vzXntq4qX34ZOZ
# 0rqY8g1Y1zaA4YwU6vhBQg
# 7jnaow1bGpKO2VkgtYE8Vv
# 4WfSDuJ4MrpdSSCEOanwzD
# 1mdJ39D1lrR3aWIOhgeNaE
# 0qYTZCo5Bwh1nsUFGZP3zn
# causing error:  ['0qYTZCo5Bwh1nsUFGZP3zn']
# 6vXi13WQA7ExaAcdTJ26We
# 74GrgSGucjqiQ0l7ptknoB
# 6euiFn8WzBNrl1alWp1udS
# 6oZuSPBQySlwY33BhdIm11
# 2He7ZIvNyBo188a6hvS0zT
# 55HtKTQeAdPbLz8NtlkaKB
# 5sMugAU31Ug5SAUUbhBIKU
# 25gD4PQjxCLnwIY2n23aEl
# 099tjv6oy2opbpCOA3nBwX
# 45bE4HXI0AwGZXfZtMp8JR
# 3MkDbpHIHxmxOzqUAClMj3
# 25ZAibhr3bdlMCLmubZDVt
# 2Aq4sw2LKalsQ7m4pzLZ88
# 0Fpen1PTuEnCmOJtUU9Iud
# 39wukX8RnU7JSi0Isvewhp
# 0V8jXwVQcxaoyYVvxNoQAB
# causing error:  ['0qYTZCo5Bwh1nsUFGZP3zn', '0V8jXwVQcxaoyYVvxNoQAB']
# 3kXj5gkguqqg3gr815EW4Y
# 3IQe7wqTyXxkqeMR8is76T
# 5icOoE6VgqFKohjWWNp0Ac
# 6rvJ7sDyoC340bzusipOU6
# 04DwTuZ2VBdJCCC5TROn7L
# 4ds6k3is0RNjqZoZC8T9z7
# 7DarbtpxRUG5POF3ifwu61
# 3lTL4LdFKVF51lseI2nk5D
# 6JV2JOEocMgcZxYSZelKcc
# 0U6bQIAh6MCGo1xjbIIx2S
# 4hKWUzhQWsOkgT6LnDEASe
# 7IyUAI0tMMgXXlgA9epukn
# 5q0yLR3cBWjZ12pdnTNxYp
# 7gRPkCEa3YMaxET5ZYT7Ni
# 38RIEav39FGi86jppxO0du
# 3uayvzcbqFydIbgUeC6EJh
# 4JnJ9ACXmtLkpH61ZvFSaM
# 3yndKI4zWEyC36BQYrdKBA
# 4ejyZ4uJEXUURcgKp1kP8v
# 27SdWb2rFzO6GWiYDBTD9j
# 5HFUJIjkg7DgP3EuWtZ1rA
# 0Cn8NxJZz7zUlsaA3rXoIU
# 39Yp9wwQiSRIDOvrVg7mbk
# 7G8g5Zrr5rj2OoKoXGnRb1
# 0aSFXdXIOnQz9GTxU4zZ2f
# 1wPQdWUqzqCRKjdP5zOXQy
# 0t56PQcJCfvl6dsK1qlfzD
# 3lHuDW8SiPtnIMmaTiDFVe
# 2kju4JyRnNmiwQYhFrLgKy
# 2U5WueTLIK5WJLD7mvDODv
# 1MMeScdLmniNyO4WMuoIxb
# 4QtiVmuA88tPQiCOHZuQ5b
# 1KSqYYJFyfTecXFk9M0prc
# 7KbF6AdprOXEEHlsq11Z6d
# 1qMx707PFdFXdwLvcUTNz3
# 1BU2rpXjavf2YHvTyfmku4
# 0eYjxzcj4s5vwIekMuf6ZI
# 6o8ogTrSX8H0F66Pdz3Tsc
# 5yY9lUy8nbvjM1Uyo1Uqoc
# 2DnfYBSG1cEcEYieldgp2X
# 4SJHHpKhcuXwDsCsPqshXj
# 2KklXplRtxMsBYo474Es0w
# 0uwaiApk6k7k9POyFjTKeR
# 4xlrALxuaCf9yZBHJeTSG6

# %%
print(len(charts_features_df))

# null values left
print(charts_features_df.isnull().sum())
charts_features_df.head()
# Out:
# 6008
# ID                  0
# duration_ms         0
# popularity          0
# acousticness        0
# danceability        0
# energy              0
# key                 0
# instrumentalness    0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# valence             0
# tempo               0
# loud_start          0
# dtype: int64
#                        ID duration_ms popularity  acousticness  danceability  \
# 0  3g9yjJFOtZkGAYoVz0WpeJ      211408          0        0.2270         0.642
# 1  5hcWlcZE9vFMeaFaTjo1Zf      203085         61        0.0354         0.682
# 2  6kPJZM97LwdG9QIsT7khp6      222653         73        0.0441         0.737
# 3  2z0ZSojJWKDOCucLfTNU3K      258765         40        0.0196         0.792
# 4  3v6a43VROJNCWoJXTCprLu      242181         43        0.6720         0.763
#
#    energy key instrumentalness  liveness  loudness mode  speechiness  valence  \
# 0   0.470   2                0     0.248    -9.258    1       0.0310    0.607
# 1   0.862   7                0     0.341    -4.824    1       0.1720    0.643
# 2   0.636  11         6.66e-05     0.350    -4.546    0       0.0437    0.565
# 3   0.665  10         5.08e-06     0.597    -5.676    0       0.1000    0.786
# 4   0.423  11         2.95e-05     0.105   -11.023    0       0.0872    0.393
#
#      tempo  loud_start
# 0  130.013     -12.184
# 1  122.975     -10.973
# 2  105.005      -6.356
# 3   90.001      -6.641
# 4  110.032     -18.863

# %% [markdown]
# # Leftjoin
# left join the 13282 charts entries with the dataframe of the unique 5872 music features

# %%
charts_df=charts_df_basic_top20.merge(charts_features_df, how='left',on='ID')

# %%
#drop rows with missing music data - most notably Baccara "Yes Sir I can boogey"
charts_df.dropna(axis=0, how='any', thresh=17, inplace=True)
len(charts_df)
# Out:
# 13699

# %% [markdown]
# # EXPORT TO CSV
# Analysis will happen in jupyter notebook 'analysis'

# %%
charts_df.rename(columns={'length':'duration_ms'})
# Out:
#        Position                      Track Name                Artist  \
# 0             1                          Sucker        Jonas Brothers
# 1             2                         Undrunk              FLETCHER
# 2             3                Don't Call Me Up                 Mabel
# 3             4                       Moonlight               Gaullin
# 4             5                 i'm so tired...                  Lauv
# ...         ...                             ...                   ...
# 13696        16             ゴーカ!ごーかい!?ファントムシーフ!         ハロー、ハッピーワールド!
# 13697        17                           Wager              ichikoro
# 13698        18                     見ざる聞かざる言わざる  WEDNESDAY CAMPANELLA
# 13699        19  インターネットじゃカッコいいのに feat. Chiyoko                   uno
# 13700        20       Say Amen (Saturday Night)   Panic! At The Disco
#
#                                                      URL  \
# 0      https://open.spotify.com/track/4y3OI86AEP6PQoD...
# 1      https://open.spotify.com/track/5SHhPFh68OhUmuR...
# 2      https://open.spotify.com/track/5WHTFyqSii0lmT9...
# 3      https://open.spotify.com/track/0A5gdlrpAuQqZ2i...
# 4      https://open.spotify.com/track/7COXchtUOMd6uIT...
# ...                                                  ...
# 13696  https://open.spotify.com/track/6Mfr5EHIrMhZefe...
# 13697  https://open.spotify.com/track/7kKEqFQaPTmQgW7...
# 13698  https://open.spotify.com/track/3unHkbItvg3HXYm...
# 13699  https://open.spotify.com/track/5KBshrM1lL0a9j1...
# 13700  https://open.spotify.com/track/4qSsjDGXplb6422...
#
#                       filename                      ID       date country  \
# 0      2019-03-27-in-viral.csv  4y3OI86AEP6PQoDE6olYhO 2019-03-27      in
# 1      2019-03-27-in-viral.csv  5SHhPFh68OhUmuRPymKX9d 2019-03-27      in
# 2      2019-03-27-in-viral.csv  5WHTFyqSii0lmT9R21abT8 2019-03-27      in
# 3      2019-03-27-in-viral.csv  0A5gdlrpAuQqZ2iFgnqBFW 2019-03-27      in
# 4      2019-03-27-in-viral.csv  7COXchtUOMd6uIT6HvmRaI 2019-03-27      in
# ...                        ...                     ...        ...     ...
# 13696  2018-04-01-jp-viral.csv  6Mfr5EHIrMhZefeWuOPuiO 2018-04-01      jp
# 13697  2018-04-01-jp-viral.csv  7kKEqFQaPTmQgW7wadHspJ 2018-04-01      jp
# 13698  2018-04-01-jp-viral.csv  3unHkbItvg3HXYmIwZVwJW 2018-04-01      jp
# 13699  2018-04-01-jp-viral.csv  5KBshrM1lL0a9j18Rx7k5S 2018-04-01      jp
# 13700  2018-04-01-jp-viral.csv  4qSsjDGXplb6422X2INvFW 2018-04-01      jp
#
#        group duration_ms popularity  acousticness  danceability  energy key  \
# 0      viral      181040          9        0.0427         0.842   0.734   1
# 1      viral      183428          0        0.4550         0.679   0.572   5
# 2      viral      178480         79        0.2960         0.674   0.881   9
# 3      viral      173066         72        0.0529         0.813   0.761  10
# 4      viral      162582         11        0.1760         0.599   0.733  11
# ...      ...         ...        ...           ...           ...     ...  ..
# 13696  viral      218640         28        0.1580         0.575   0.960   8
# 13697  viral      317811         23        0.0270         0.340   0.911  11
# 13698  viral      232886          3        0.5640         0.689   0.594   6
# 13699  viral      262010          3        0.0667         0.741   0.813   9
# 13700  viral      189186         43        0.1670         0.491   0.867   6
#
#       instrumentalness  liveness  loudness mode  speechiness  valence  \
# 0                    0    0.1060    -5.065    0       0.0588    0.952
# 1             2.41e-06    0.1270    -6.703    1       0.0781    0.542
# 2             3.01e-06    0.0793    -2.853    1       0.1470    0.234
# 3               0.0119    0.3370    -5.687    0       0.0850    0.290
# 4                    0    0.2420    -7.058    1       0.2030    0.534
# ...                ...       ...       ...  ...          ...      ...
# 13696         0.000104    0.3260    -1.187    0       0.0587    0.719
# 13697            0.878    0.0672    -7.353    0       0.0498    0.581
# 13698            0.289    0.3180   -10.063    1       0.0607    0.597
# 13699            0.523    0.0256    -5.379    0       0.0455    0.564
# 13700                0    0.4580    -2.313    0       0.1030    0.602
#
#          tempo  loud_start
# 0      137.958     -11.142
# 1       92.859      -8.190
# 2       98.994      -5.559
# 3      124.957      -5.704
# 4      102.211     -12.880
# ...        ...         ...
# 13696  107.495      -2.885
# 13697  125.282     -19.217
# 13698  135.968     -14.818
# 13699  120.006      -9.823
# 13700  167.965      -7.388
#
# [13699 rows x 23 columns]

# %%
charts_df.to_csv(r'data/analysis/regional_charts_songs_2017-2020.csv', index = False)

# %%
###########################################
